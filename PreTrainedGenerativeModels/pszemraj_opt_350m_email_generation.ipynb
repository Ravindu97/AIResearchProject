# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.33.3-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 30.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 86.5 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.33.3

# %%
import pandas as pd

# %%
df = pd.read_csv('EmailGeneration.csv')

# %%
df
# Out:
#                                               Subject Label
# 0     URGENT: Your bank account has been compromised!  Spam
# 1                                FREE Viagra for men!  Spam
# 2                             You've won the lottery!  Spam
# 3                 Your credit card has been declined.  Spam
# 4             Your computer is infected with a virus!  Spam
# 5                          Lose weight fast and easy!  Spam
# 6               Make money online quickly and easily!  Spam
# 7                                     Get rich quick!  Spam
# 8   Invest in our new cryptocurrency and earn big ...  Spam
# 9                 Click here to claim your free gift!  Spam
# 10            Enter our giveaway to win a new iPhone!  Spam
# 11          You've been selected for a special offer!  Spam
# 12           Don't miss out on our limited-time sale!  Spam
# 13              Act now and save 50% on all products!  Spam
# 14                   Order now and get free shipping!  Spam
# 15  Subscribe to our newsletter and get 10% off yo...  Spam
# 16     Click here to unsubscribe from our newsletter.   Ham
# 17                    Your bank account is overdrawn.  Spam
# 18             Your account is about to be suspended.  Spam
# 19                               Verify your account.  Spam
# 20                   Update your account information.  Spam
# 21                          Important security alert.  Spam
# 22      Limited-time offer: Get 50% off all products!  Spam
# 23              Free shipping on all orders over $50!  Spam
# 24        New product release: The all-new iPhone 14!  Spam
# 25             You're pre-approved for a credit card!  Spam
# 26      Apply now for a loan with low interest rates!  Spam
# 27                Get a free quote on auto insurance!  Spam
# 28  Your social security number has been compromised.  Spam
# 29                          Your tax refund is ready!  Spam
# 30              You've been selected for a jury duty.  Spam
# 31                                  You've been sued.  Spam
# 32                            You've been subpoenaed.  Spam
# 33                     Your car has been repossessed.  Spam
# 34                 Your house has been foreclosed on.  Spam
# 35                   You've been fired from your job.  Spam
# 36                    Your spouse is cheating on you.  Spam
# 37                             Your child is missing.  Spam
# 38  Your bank account has been credited with $10,000!  Spam
# 39  You've been selected to receive a government g...  Spam
# 40    You're eligible for a free refund from the IRS!  Spam
# 41       Your credit score has improved by 50 points!  Spam
# 42  You've been approved for a new credit card wit...  Spam
# 43     You've been invited to join an exclusive club!  Spam
# 44                You've won a trip to the Caribbean!  Spam
# 45              You're the lucky winner of a new car!  Spam
# 46  You've been selected to participate in a clini...  Spam
# 47              Your investment has tripled in value!  Spam
# 48            You're the sole heir to a vast fortune!  Spam
# 49  You've been invited to a job interview at Google!  Spam
# 50           Your child has been accepted to Harvard!  Spam
# 51            You've been invited to speak at the UN!  Spam
# 52    You're the next president of the United States!  Spam
# 53                    Click here to claim your prize!  Spam
# 54                      Act now to avoid missing out!  Spam
# 55                Don't miss this limited-time offer!  Spam
# 56                          This is your last chance!  Spam
# 57                             Don't wait any longer!  Spam
# 58                                         Do it now!  Spam

# %%
from transformers import pipeline

model_tag = "pszemraj/opt-350m-email-generation"
generator = pipeline(
              'text-generation',
              model=model_tag,
              use_fast=False,
              do_sample=False,
              early_stopping=True,
            )
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/649 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/894 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/999k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/434 [00:00<?, ?B/s]

# %%
def generate_email(email_subject):
  email_body = generator(email_subject)
  return email_body

# %%
# Create a new column for the generated body
df['Generated body'] = None

# %%
# Iterate through the data frame and append the generated body
for index, row in df.iterrows():
  email_subject = row['Subject']
  email_body = generate_email(email_subject)
  df.loc[index, 'Generated body'] = email_body

# Save the updated data frame
df.to_csv('spam-mails-dataset-pszemraj_opt-350m-email-generation.csv', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:399: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
